# %%
import pandas as pd
import numpy as np

# %%
#df=pd.read_csv('/Users/saurabh/cleaning_data/data/unclean_data.csv')  # returns a unicode-decode error

# %%
#solution1-UTF Encoding
#solution2-use text editor and save it as 'UTF-8' encoding
df1=pd.read_csv('/Users/saurabh/cleaning_data/data/unclean_data.csv',encoding='latin1')
df1.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
#column names are inconsistent
#some are lower_case/Upper_case

# %%
df1.columns.str.upper()
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
df1.columns=df1.columns.str.title()

# %%
df1.head()
# Out:
#                                   Movie_Title  Num_Critic_For_Reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    Duration Director_Facebook_Likes  Actor_3_Facebook_Likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    Actor_1_Facebook_Likes      Gross  Num_Voted_Users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
#Renaming columns
df1.rename(columns={'Duration':'Length'},inplace=True)

# %%
df1.head()
# Out:
#                                   Movie_Title  Num_Critic_For_Reviews  Length  \
# 0                                    Avatar?ÿ                     723   178.0
# 1  Pirates of the Caribbean: At World's End?ÿ                     302     NaN
# 2                                   Spectre?ÿ                     602   148.0
# 3                     The Dark Knight Rises?ÿ                     813     NaN
# 4                               John Carter?ÿ                     462   132.0
#
#   Director_Facebook_Likes  Actor_3_Facebook_Likes  Actor_1_Facebook_Likes  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
# ...

# %%
#Check for missing data
#1 .info
#2 isnull().any()
#3 isnull().sum()

# %%
df1.info()        #14 rows,so each column is supposed to have 14 entries.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 16 columns):
# Movie_Title                  14 non-null object
# Num_Critic_For_Reviews       14 non-null int64
# Length                       11 non-null float64
# Director_Facebook_Likes      12 non-null object
# Actor_3_Facebook_Likes       14 non-null int64
# Actor_1_Facebook_Likes       14 non-null int64
# Gross                        14 non-null int64
# Num_Voted_Users              13 non-null float64
# Cast_Total_Facebook_Likes    12 non-null float64
# Facenumber_In_Poster         9 non-null float64
# Num_User_For_Reviews         14 non-null int64
# Budget                       14 non-null int64
# Title_Year                   14 non-null int64
# Actor_2_Facebook_Likes       13 non-null float64
# Imdb_Score                   14 non-null float64
# Title_Year.1                 7 non-null float64
# dtypes: float64(7), int64(7), object(2)
# memory usage: 1.8+ KB

# %%
#2nd way
df1.isnull().any()
# Out:
# Movie_Title                  False
# Num_Critic_For_Reviews       False
# Length                        True
# Director_Facebook_Likes       True
# Actor_3_Facebook_Likes       False
# Actor_1_Facebook_Likes       False
# Gross                        False
# Num_Voted_Users               True
# Cast_Total_Facebook_Likes     True
# Facenumber_In_Poster          True
# Num_User_For_Reviews         False
# Budget                       False
# Title_Year                   False
# Actor_2_Facebook_Likes        True
# Imdb_Score                   False
# Title_Year.1                  True
# dtype: bool

# %%
#3rd way
df1.isnull().sum()         #df.isnull().sum().sum() =total missing values
# Out:
# Movie_Title                  0
# Num_Critic_For_Reviews       0
# Length                       3
# Director_Facebook_Likes      2
# Actor_3_Facebook_Likes       0
# Actor_1_Facebook_Likes       0
# Gross                        0
# Num_Voted_Users              1
# Cast_Total_Facebook_Likes    2
# Facenumber_In_Poster         5
# Num_User_For_Reviews         0
# Budget                       0
# Title_Year                   0
# Actor_2_Facebook_Likes       1
# Imdb_Score                   0
# Title_Year.1                 7
# dtype: int64

# %%
#Missing data solutions
#add a default value
#delete the row/column with missing data,unless its important
#Interpolate the rows
#Replace

# %%
#filling with a default value
df1.fillna(0).head() #make sure that there are not any relevant zeroes already as it might affect the model result
# Out:
#                                   Movie_Title  Num_Critic_For_Reviews  Length  \
# 0                                    Avatar?ÿ                     723   178.0
# 1  Pirates of the Caribbean: At World's End?ÿ                     302     0.0
# 2                                   Spectre?ÿ                     602   148.0
# 3                     The Dark Knight Rises?ÿ                     813     0.0
# 4                               John Carter?ÿ                     462   132.0
#
#   Director_Facebook_Likes  Actor_3_Facebook_Likes  Actor_1_Facebook_Likes  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
# ...

# %%
#filling with mean
df1['Length'].mean()
# Out:
# 150.72727272727272

# %%
df1.Length.fillna(df1['Length'].mean(),inplace=True)

# %%
df1.head()
# Out:
#                                   Movie_Title  Num_Critic_For_Reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#        Length Director_Facebook_Likes  Actor_3_Facebook_Likes  \
# 0  178.000000                      10                     855
# 1  150.727273                     563                    1000
# 2  148.000000                      20                     161
# 3  150.727273                   22000                   23000
# 4  132.000000                   "475"                     530
#
#    Actor_1_Facebook_Likes      Gross  Num_Voted_Users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
#dropping na
df1.dropna()   #this works but a significant amount of data is lost
# Out:
#                                      Movie_Title  Num_Critic_For_Reviews  \
# 2                                      Spectre?ÿ                     602
# 8                      Avengers: Age of Ultron?ÿ                     635
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     Length Director_Facebook_Likes  Actor_3_Facebook_Likes  \
# 2    148.0                      20                     161
# 8    141.0                      10                   19000
# 12   106.0                     395                     393
# 13   151.0                     563                    1000
#
#     Actor_1_Facebook_Likes      Gross  Num_Voted_Users  \
# 2                    11000  200074175         275868.0
# 8                    26000  458991599         462669.0
# 12                     451  168368427         330784.0
# 13                   40000  423032628         522040.0
#
# ...

# %%
df1.dropna(thresh=2)
# Out:
#                                      Movie_Title  Num_Critic_For_Reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df1.dropna(axis=1).head(10) #drops columns
# Out:
#                                   Movie_Title  Num_Critic_For_Reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
# 5                              Spider-Man 3?ÿ                     392
# 6                                   Tangled?ÿ                     324
# 7                   Avengers: Age of Ultron?ÿ                     635
# 8                   Avengers: Age of Ultron?ÿ                     635
# 9    Harry Potter and the Half-Blood Prince?ÿ                     375
#
#        Length  Actor_3_Facebook_Likes  Actor_1_Facebook_Likes      Gross  \
# 0  178.000000                     855                    1000  760505847
# ...
