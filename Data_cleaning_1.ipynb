# %% [markdown]
# Problem fixed:column headers are values instead of columns

# %%
import pandas as pd

# %%
pew=pd.read_csv('/Users/saurabh/cleaning_data/data/pew.csv')

# %%
pew.shape  #make sure the data is in expected shape
# Out:
# (18, 11)

# %%
pew.head() #check column names got loaded properly,sometimes column names are missing and pandas
           #treat the first row as column names
# Out:
#              religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  $50-75k  \
# 0            Agnostic     27       34       60       81       76      137
# 1             Atheist     12       27       37       52       35       70
# 2            Buddhist     27       21       30       34       33       58
# 3            Catholic    418      617      732      670      638     1116
# 4  Don’t know/refused     15       14       15       11       10       35
#
#    $75-100k  $100-150k  >150k  Don't know/refused
# 0       122        109     84                  96
# 1        73         59     74                  76
# 2        62         39     53                  54
# 3       949        792    633                1489
# 4        21         17     18                 116

# %%
# data looks good but on close inspection,column names are values with some range

# %%
pew.info() #missing values?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 11 columns):
# religion              18 non-null object
# <$10k                 18 non-null int64
# $10-20k               18 non-null int64
# $20-30k               18 non-null int64
# $30-40k               18 non-null int64
# $40-50k               18 non-null int64
# $50-75k               18 non-null int64
# $75-100k              18 non-null int64
# $100-150k             18 non-null int64
# >150k                 18 non-null int64
# Don't know/refused    18 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 1.6+ KB

# %%
pew_long=pd.melt(pew,id_vars='religion',var_name='Income',value_name='Values') #fix column names

# %%
pew_long.head()
# Out:
#              religion Income  Values
# 0            Agnostic  <$10k      27
# 1             Atheist  <$10k      12
# 2            Buddhist  <$10k      27
# 3            Catholic  <$10k     418
# 4  Don’t know/refused  <$10k      15

# %%
billboard=pd.read_csv('/Users/saurabh/cleaning_data/data/billboard.csv')

# %%
billboard.head()
# Out:
#    year        artist                    track  time date.entered  wk1   wk2  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87  82.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91  87.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   81  70.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   76  76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   57  34.0
#
#     wk3   wk4   wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  \
# 0  72.0  77.0  87.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  92.0   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  68.0  67.0  66.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  72.0  69.0  67.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  25.0  17.0  17.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    wk75  wk76
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# ...

# %%
#76 weeks spread out as column names instead of rows

# %%
billboard_new=pd.melt(billboard,id_vars=['year','artist','track','time','date.entered'],var_name='Weeks',value_name='ratings')

# %%
billboard_new.head()
# Out:
#    year        artist                    track  time date.entered Weeks  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   wk1
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   wk1
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   wk1
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   wk1
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   wk1
#
#    ratings
# 0     87.0
# 1     91.0
# 2     81.0
# 3     76.0
# 4     57.0

# %%
billboard_new.shape
# Out:
# (24092, 7)
