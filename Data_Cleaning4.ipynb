# %% [markdown]
# #Problem fixed:Multiple types of observational units stored in same table

# %%
import pandas as pd

# %%
billboard=pd.read_csv('/Users/saurabh/cleaning_data/data/billboard.csv')

# %%
billboard.head(10)
# Out:
#    year          artist                    track  time date.entered  wk1  \
# 0  2000           2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1  2000         2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2  2000    3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3  2000    3 Doors Down                    Loser  4:24   2000-10-21   76
# 4  2000        504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# 5  2000            98^0  Give Me Just One Nig...  3:24   2000-08-19   51
# 6  2000         A*Teens            Dancing Queen  3:44   2000-07-08   97
# 7  2000         Aaliyah            I Don't Wanna  4:15   2000-01-29   84
# 8  2000         Aaliyah                Try Again  4:03   2000-03-18   59
# 9  2000  Adams, Yolanda            Open My Heart  5:30   2000-08-26   76
#
#     wk2   wk3   wk4    wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  \
# 0  82.0  72.0  77.0   87.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
billboard_new=pd.melt(billboard,id_vars=['year','artist','track','time','date.entered'],var_name='week')

# %%
billboard_new.head(10)
# Out:
#    year          artist                    track  time date.entered week  \
# 0  2000           2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  wk1
# 1  2000         2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  wk1
# 2  2000    3 Doors Down               Kryptonite  3:53   2000-04-08  wk1
# 3  2000    3 Doors Down                    Loser  4:24   2000-10-21  wk1
# 4  2000        504 Boyz            Wobble Wobble  3:35   2000-04-15  wk1
# 5  2000            98^0  Give Me Just One Nig...  3:24   2000-08-19  wk1
# 6  2000         A*Teens            Dancing Queen  3:44   2000-07-08  wk1
# 7  2000         Aaliyah            I Don't Wanna  4:15   2000-01-29  wk1
# 8  2000         Aaliyah                Try Again  4:03   2000-03-18  wk1
# 9  2000  Adams, Yolanda            Open My Heart  5:30   2000-08-26  wk1
#
#    value
# 0   87.0
# 1   91.0
# 2   81.0
# 3   76.0
# 4   57.0
# 5   51.0
# 6   97.0
# 7   84.0
# 8   59.0
# 9   76.0

# %%
#now each entry can have repeated entries for many weeks,not just wk1:Billboard logic
#this can be bad for data storage in long term

# %%
billboard_new.loc[billboard_new['track']=='Try Again'].head(5)  #repeated 76 times
# Out:
#       year   artist      track  time date.entered week  value
# 8     2000  Aaliyah  Try Again  4:03   2000-03-18  wk1   59.0
# 325   2000  Aaliyah  Try Again  4:03   2000-03-18  wk2   53.0
# 642   2000  Aaliyah  Try Again  4:03   2000-03-18  wk3   38.0
# 959   2000  Aaliyah  Try Again  4:03   2000-03-18  wk4   28.0
# 1276  2000  Aaliyah  Try Again  4:03   2000-03-18  wk5   21.0

# %%
billboard_songs=billboard_new[['year','artist','track','time']]   #fixing storage issue by taking only relevant pieces

# %%
billboard_songs.head()
# Out:
#    year        artist                    track  time
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15
# 2  2000  3 Doors Down               Kryptonite  3:53
# 3  2000  3 Doors Down                    Loser  4:24
# 4  2000      504 Boyz            Wobble Wobble  3:35

# %%
billboard_songs.shape     #still contains duplicates
# Out:
# (24092, 4)

# %%
billboard_songs=billboard_songs.drop_duplicates()

# %%
billboard_songs.shape    #went from 24092 rows to 317:since each song entry was repeated 76 times for 76 weeks.
# Out:
# (317, 4)

# %% [markdown]
# Comparing memory usage

# %%
billboard_songs.info()      #14.9KB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 317 entries, 0 to 316
# Data columns (total 5 columns):
# year      317 non-null int64
# artist    317 non-null object
# track     317 non-null object
# time      317 non-null object
# id        317 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 14.9+ KB

# %%
billboard_new.info()     #1.3MB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24092 entries, 0 to 24091
# Data columns (total 7 columns):
# year            24092 non-null int64
# artist          24092 non-null object
# track           24092 non-null object
# time            24092 non-null object
# date.entered    24092 non-null object
# week            24092 non-null object
# value           5307 non-null float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.3+ MB

# %%
#billboard_songs.to_csv('billboard_cleaned.csv',index=False)
